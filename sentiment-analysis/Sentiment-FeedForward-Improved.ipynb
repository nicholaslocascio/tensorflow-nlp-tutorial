# %% [markdown]
# # TensorFlow Simple Sentiment Analysis Improved

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
# tf.reset_default_graph()
session = tf.InteractiveSession()
import utils
import numpy as np

# %%
X, y, index_to_word, sentences = utils.load_sentiment_data_bow()
X_train, y_train, X_test, y_test = utils.split_data(X, y)
vocab_size = X.shape[1]
n_classes = y.shape[1]

s_i = 50
print("Sentence:", sentences[s_i])
print("BOW:", utils.bow_to_dict(X[s_i,:], index_to_word))
print("Label:", utils.label_to_desc(y[s_i]))
# Out:
# ('Sentence:', '@VirginAmerica Is flight 769 on it\'s way? Was supposed to take off 30 minutes ago. Website still shows "On Time" not "In Flight". Thanks.')
# ('BOW:', {'is': 1.0, 'it': 1.0, 'thanks': 1.0, 'in': 1.0, 'still': 1.0, u'<UNK>': 1.0, '"': 4.0, "'": 1.0, '.': 3.0, 'to': 1.0, 'take': 1.0, 'way': 1.0, 'was': 1.0, '?': 1.0, 'shows': 1.0, 'website': 1.0, 'flight': 2.0, '@virginamerica': 1.0, 'not': 1.0, 'ago': 1.0, 'on': 2.0, 'off': 1.0, '30': 1.0, 's': 1.0, 'supposed': 1.0, 'time': 1.0, 'minutes': 1.0})
# ('Label:', 'negative')

# %%
data_placeholder = tf.placeholder(tf.float32, shape=(None, vocab_size), name='data_placeholder')
labels_placeholder = tf.placeholder(tf.float32, shape=(None, n_classes), name='labels_placeholder')
keep_prob_placeholder = tf.placeholder(tf.float32, name='keep_prob_placeholder')

# %%
# Helper function for fully connected layers

def linear(input_, output_size, layer_scope, stddev=0.02, bias_start=0.0):
    shape = input_.get_shape().as_list()

    with tf.variable_scope(layer_scope):
        matrix = tf.get_variable("Matrix", [shape[1], output_size], tf.float32,
                                 tf.random_normal_initializer(stddev=stddev))
        bias = tf.get_variable("bias", [output_size],
            initializer=tf.constant_initializer(bias_start))
        return tf.matmul(input_, matrix) + bias

# %%
# Define Computation Graphs

n_hidden_units_h0 = 512
n_hidden_units_h1 = 256

with tf.variable_scope('hidden_layers'):
    hidden0 = tf.nn.relu(linear(data_placeholder, n_hidden_units_h0, 'hidden0'))
    hidden1 = tf.nn.relu(linear(hidden0, n_hidden_units_h1, 'hidden1'))

logits = linear(hidden1, n_classes, 'output_layer')

# %%
# Define Loss Function + Optimizer
loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, labels_placeholder))

loss_sum = tf.scalar_summary('loss', loss)

optimizer = tf.train.GradientDescentOptimizer(0.00005).minimize(loss)
prediction = tf.nn.softmax(logits)
prediction_is_correct = tf.equal(
    tf.argmax(logits, 1), tf.argmax(labels_placeholder, 1))
accuracy = tf.reduce_mean(tf.cast(prediction_is_correct, tf.float32))
accuracy_sum = tf.scalar_summary('accuracy', accuracy)

# %%
# Train loop

num_steps = 2000
batch_size = 128
keep_prob_rate = 0.75

tf.initialize_all_variables().run()
merged_summary_op = tf.merge_summary([loss_sum, accuracy_sum])
train_writer = tf.train.SummaryWriter("./feed-forward-logs-train", session.graph)
test_writer = tf.train.SummaryWriter("./feed-forward-logs-test", session.graph)

for step in xrange(num_steps):
    offset = (step * batch_size) % (X_train.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = X_train[offset:(offset + batch_size), :]
    batch_labels = y_train[offset:(offset + batch_size), :]
    # We built our networking using placeholders. It's like we've made reservations for a party of 6.
    # So use feed_dict to fill what we reserved. And we can't show up with 9 people. 

    feed_dict_train = {data_placeholder: batch_data, labels_placeholder : batch_labels, keep_prob_placeholder: keep_prob_rate}
    # Run the optimizer, get the loss, get the predictions.
    # We can run multiple things at once and get their outputs
    _, loss_value_train, predictions_value_train, accuracy_value_train, merged_sum = session.run(
      [optimizer, loss, prediction, accuracy, merged_summary_op], feed_dict=feed_dict_train)
    train_writer.add_summary(merged_sum, step)
    if (step % 10 == 0):
        print "Minibatch train loss at step", step, ":", loss_value_train
        print "Minibatch train accuracy: %.3f%%" % accuracy_value_train
        feed_dict_test = {data_placeholder: X_test, labels_placeholder: y_test, keep_prob_placeholder: 1.0}
        loss_value_test, predictions_value_test, accuracy_value_test, merged_sum = session.run(
            [loss, prediction, accuracy, merged_summary_op], feed_dict=feed_dict_test)
        test_writer.add_summary(merged_sum, step)
    
        print "Test loss: %.3f" % loss_value_test
        print "Test accuracy: %.3f%%" % accuracy_value_test
# Out:
# Minibatch train loss at step 0 : 1.09872
# Minibatch train accuracy: 0.375%
# Test loss: 1.102
# Test accuracy: 0.178%
# Minibatch train loss at step 10 : 1.10095
# Minibatch train accuracy: 0.180%
# Test loss: 1.101
# Test accuracy: 0.180%
# Minibatch train loss at step 20 : 1.10018
# Minibatch train accuracy: 0.203%
# Test loss: 1.101
# Test accuracy: 0.182%
# Minibatch train loss at step 30 : 1.10063
# Minibatch train accuracy: 0.242%
# Test loss: 1.101
# Test accuracy: 0.185%
# Minibatch train loss at step 40 : 1.09992
# Minibatch train accuracy: 0.211%
# Test loss: 1.101
# Test accuracy: 0.186%
# Minibatch train loss at step 50 : 1.09951
# Minibatch train accuracy: 0.266%
# Test loss: 1.101
# Test accuracy: 0.189%
# Minibatch train loss at step 60 : 1.09946
# Minibatch train accuracy: 0.289%
# Test loss: 1.101
# Test accuracy: 0.190%
# Minibatch train loss at step 70 : 1.10037
# Minibatch train accuracy: 0.195%
# Test loss: 1.101
# Test accuracy: 0.192%
# Minibatch train loss at step 80 : 1.10137
# Minibatch train accuracy: 0.141%
# Test loss: 1.101
# Test accuracy: 0.195%
# Minibatch train loss at step 90 : 1.10026
# Minibatch train accuracy: 0.172%
# Test loss: 1.101
# Test accuracy: 0.199%
# Minibatch train loss at step 100 : 1.09955
# Minibatch train accuracy: 0.250%
# Test loss: 1.101
# Test accuracy: 0.201%
# Minibatch train loss at step 110 : 1.09944
# Minibatch train accuracy: 0.273%
# Test loss: 1.100
# Test accuracy: 0.208%
# Minibatch train loss at step 120 : 1.09955
# Minibatch train accuracy: 0.266%
# Test loss: 1.100
# Test accuracy: 0.214%
# Minibatch train loss at step 130 : 1.09964
# Minibatch train accuracy: 0.297%
# Test loss: 1.100
# Test accuracy: 0.215%
# Minibatch train loss at step 140 : 1.0991
# Minibatch train accuracy: 0.297%
# Test loss: 1.100
# Test accuracy: 0.217%
# Minibatch train loss at step 150 : 1.09975
# Minibatch train accuracy: 0.305%
# Test loss: 1.100
# Test accuracy: 0.219%
# Minibatch train loss at step 160 : 1.09908
# Minibatch train accuracy: 0.266%
# Test loss: 1.100
# Test accuracy: 0.220%
# Minibatch train loss at step 170 : 1.10047
# Minibatch train accuracy: 0.141%
# Test loss: 1.100
# Test accuracy: 0.231%
# Minibatch train loss at step 180 : 1.09923
# Minibatch train accuracy: 0.219%
# Test loss: 1.100
# Test accuracy: 0.239%
# Minibatch train loss at step 190 : 1.0984
# Minibatch train accuracy: 0.273%
# Test loss: 1.100
# Test accuracy: 0.242%
# Minibatch train loss at step 200 : 1.09874
# Minibatch train accuracy: 0.297%
# Test loss: 1.100
# Test accuracy: 0.248%
# Minibatch train loss at step 210 : 1.09868
# Minibatch train accuracy: 0.312%
# Test loss: 1.099
# Test accuracy: 0.250%
# Minibatch train loss at step 220 : 1.09903
# Minibatch train accuracy: 0.328%
# Test loss: 1.099
# Test accuracy: 0.251%
# Minibatch train loss at step 230 : 1.09879
# Minibatch train accuracy: 0.320%
# Test loss: 1.099
# Test accuracy: 0.254%
# Minibatch train loss at step 240 : 1.09923
# Minibatch train accuracy: 0.266%
# Test loss: 1.099
# Test accuracy: 0.258%
# Minibatch train loss at step 250 : 1.09849
# Minibatch train accuracy: 0.305%
# Test loss: 1.099
# Test accuracy: 0.259%
# Minibatch train loss at step 260 : 1.09924
# Minibatch train accuracy: 0.203%
# Test loss: 1.099
# Test accuracy: 0.270%
# Minibatch train loss at step 270 : 1.09873
# Minibatch train accuracy: 0.250%
# Test loss: 1.099
# Test accuracy: 0.287%
# Minibatch train loss at step 280 : 1.09778
# Minibatch train accuracy: 0.328%
# Test loss: 1.099
# Test accuracy: 0.289%
# Minibatch train loss at step 290 : 1.09818
# Minibatch train accuracy: 0.320%
# Test loss: 1.099
# Test accuracy: 0.297%
# Minibatch train loss at step 300 : 1.09809
# Minibatch train accuracy: 0.359%
# Test loss: 1.099
# Test accuracy: 0.304%
# Minibatch train loss at step 310 : 1.0982
# Minibatch train accuracy: 0.391%
# Test loss: 1.098
# Test accuracy: 0.307%
# Minibatch train loss at step 320 : 1.09815
# Minibatch train accuracy: 0.344%
# Test loss: 1.098
# Test accuracy: 0.309%
# Minibatch train loss at step 330 : 1.09795
# Minibatch train accuracy: 0.344%
# Test loss: 1.098
# Test accuracy: 0.313%
# Minibatch train loss at step 340 : 1.09879
# Minibatch train accuracy: 0.289%
# Test loss: 1.098
# Test accuracy: 0.313%
# Minibatch train loss at step 350 : 1.0975
# Minibatch train accuracy: 0.406%
# Test loss: 1.098
# Test accuracy: 0.322%
# Minibatch train loss at step 360 : 1.09704
# Minibatch train accuracy: 0.461%
# Test loss: 1.098
# Test accuracy: 0.336%
# Minibatch train loss at step 370 : 1.09776
# Minibatch train accuracy: 0.391%
# Test loss: 1.098
# Test accuracy: 0.348%
# Minibatch train loss at step 380 : 1.09742
# Minibatch train accuracy: 0.367%
# Test loss: 1.098
# Test accuracy: 0.353%
# Minibatch train loss at step 390 : 1.09791
# Minibatch train accuracy: 0.359%
# Test loss: 1.098
# Test accuracy: 0.360%
# Minibatch train loss at step 400 : 1.09819
# Minibatch train accuracy: 0.344%
# Test loss: 1.098
# Test accuracy: 0.366%
# Minibatch train loss at step 410 : 1.09854
# Minibatch train accuracy: 0.289%
# Test loss: 1.098
# Test accuracy: 0.370%
# Minibatch train loss at step 420 : 1.09719
# Minibatch train accuracy: 0.430%
# Test loss: 1.098
# Test accuracy: 0.373%
# Minibatch train loss at step 430 : 1.09797
# Minibatch train accuracy: 0.422%
# Test loss: 1.097
# Test accuracy: 0.378%
# Minibatch train loss at step 440 : 1.09598
# Minibatch train accuracy: 0.508%
# Test loss: 1.097
# Test accuracy: 0.389%
# Minibatch train loss at step 450 : 1.09584
# Minibatch train accuracy: 0.547%
# Test loss: 1.097
# Test accuracy: 0.403%
# Minibatch train loss at step 460 : 1.09683
# Minibatch train accuracy: 0.438%
# Test loss: 1.097
# Test accuracy: 0.414%
# Minibatch train loss at step 470 : 1.09663
# Minibatch train accuracy: 0.430%
# Test loss: 1.097
# Test accuracy: 0.425%
# Minibatch train loss at step 480 : 1.09691
# Minibatch train accuracy: 0.422%
# Test loss: 1.097
# Test accuracy: 0.438%
# Minibatch train loss at step 490 : 1.09795
# Minibatch train accuracy: 0.352%
# Test loss: 1.097
# Test accuracy: 0.447%
# Minibatch train loss at step 500 : 1.09827
# Minibatch train accuracy: 0.359%
# Test loss: 1.097
# Test accuracy: 0.452%
# Minibatch train loss at step 510 : 1.09673
# Minibatch train accuracy: 0.461%
# Test loss: 1.097
# Test accuracy: 0.455%
# Minibatch train loss at step 520 : 1.09771
# Minibatch train accuracy: 0.406%
# Test loss: 1.097
# Test accuracy: 0.459%
# Minibatch train loss at step 530 : 1.09567
# Minibatch train accuracy: 0.500%
# Test loss: 1.096
# Test accuracy: 0.467%
# Minibatch train loss at step 540 : 1.09534
# Minibatch train accuracy: 0.594%
# Test loss: 1.096
# Test accuracy: 0.476%
# Minibatch train loss at step 550 : 1.0955
# Minibatch train accuracy: 0.555%
# Test loss: 1.096
# Test accuracy: 0.481%
# Minibatch train loss at step 560 : 1.09475
# Minibatch train accuracy: 0.562%
# Test loss: 1.096
# Test accuracy: 0.492%
# Minibatch train loss at step 570 : 1.0962
# Minibatch train accuracy: 0.422%
# Test loss: 1.096
# Test accuracy: 0.500%
# Minibatch train loss at step 580 : 1.09686
# Minibatch train accuracy: 0.430%
# Test loss: 1.096
# Test accuracy: 0.507%
# Minibatch train loss at step 590 : 1.09811
# Minibatch train accuracy: 0.305%
# Test loss: 1.096
# Test accuracy: 0.511%
# Minibatch train loss at step 600 : 1.09544
# Minibatch train accuracy: 0.539%
# Test loss: 1.096
# Test accuracy: 0.514%
# Minibatch train loss at step 610 : 1.09784
# Minibatch train accuracy: 0.344%
# Test loss: 1.096
# Test accuracy: 0.516%
# Minibatch train loss at step 620 : 1.09438
# Minibatch train accuracy: 0.648%
# Test loss: 1.096
# Test accuracy: 0.525%
# Minibatch train loss at step 630 : 1.09509
# Minibatch train accuracy: 0.602%
# Test loss: 1.095
# Test accuracy: 0.539%
# Minibatch train loss at step 640 : 1.09545
# Minibatch train accuracy: 0.555%
# Test loss: 1.095
# Test accuracy: 0.547%
# Minibatch train loss at step 650 : 1.09355
# Minibatch train accuracy: 0.562%
# Test loss: 1.095
# Test accuracy: 0.555%
# Minibatch train loss at step 660 : 1.09631
# Minibatch train accuracy: 0.461%
# Test loss: 1.095
# Test accuracy: 0.563%
# Minibatch train loss at step 670 : 1.09679
# Minibatch train accuracy: 0.461%
# Test loss: 1.095
# Test accuracy: 0.573%
# Minibatch train loss at step 680 : 1.09876
# Minibatch train accuracy: 0.297%
# Test loss: 1.095
# Test accuracy: 0.576%
# Minibatch train loss at step 690 : 1.09523
# Minibatch train accuracy: 0.555%
# Test loss: 1.095
# Test accuracy: 0.577%
# Minibatch train loss at step 700 : 1.09795
# Minibatch train accuracy: 0.344%
# Test loss: 1.095
# Test accuracy: 0.577%
# Minibatch train loss at step 710 : 1.09282
# Minibatch train accuracy: 0.742%
# Test loss: 1.095
# Test accuracy: 0.586%
# Minibatch train loss at step 720 : 1.09504
# Minibatch train accuracy: 0.539%
# Test loss: 1.095
# Test accuracy: 0.593%
# Minibatch train loss at step 730 : 1.09543
# Minibatch train accuracy: 0.539%
# Test loss: 1.095
# Test accuracy: 0.598%
# Minibatch train loss at step 740 : 1.09266
# Minibatch train accuracy: 0.703%
# Test loss: 1.094
# Test accuracy: 0.607%
# Minibatch train loss at step 750 : 1.09523
# Minibatch train accuracy: 0.547%
# Test loss: 1.094
# Test accuracy: 0.612%
# Minibatch train loss at step 760 : 1.0971
# Minibatch train accuracy: 0.414%
# Test loss: 1.094
# Test accuracy: 0.617%
# Minibatch train loss at step 770 : 1.09755
# Minibatch train accuracy: 0.398%
# Test loss: 1.094
# Test accuracy: 0.617%
# Minibatch train loss at step 780 : 1.09652
# Minibatch train accuracy: 0.430%
# Test loss: 1.094
# Test accuracy: 0.617%
# Minibatch train loss at step 790 : 1.09742
# Minibatch train accuracy: 0.375%
# Test loss: 1.094
# Test accuracy: 0.620%
# Minibatch train loss at step 800 : 1.09257
# Minibatch train accuracy: 0.719%
# Test loss: 1.094
# Test accuracy: 0.624%
# Minibatch train loss at step 810 : 1.09437
# Minibatch train accuracy: 0.602%
# Test loss: 1.094
# Test accuracy: 0.631%
# Minibatch train loss at step 820 : 1.09365
# Minibatch train accuracy: 0.617%
# Test loss: 1.094
# Test accuracy: 0.636%
# Minibatch train loss at step 830 : 1.09188
# Minibatch train accuracy: 0.719%
# Test loss: 1.094
# Test accuracy: 0.640%
# Minibatch train loss at step 840 : 1.09424
# Minibatch train accuracy: 0.586%
# Test loss: 1.093
# Test accuracy: 0.644%
# Minibatch train loss at step 850 : 1.09812
# Minibatch train accuracy: 0.312%
# Test loss: 1.093
# Test accuracy: 0.645%
# Minibatch train loss at step 860 : 1.09685
# Minibatch train accuracy: 0.398%
# Test loss: 1.093
# Test accuracy: 0.648%
# Minibatch train loss at step 870 : 1.09762
# Minibatch train accuracy: 0.320%
# Test loss: 1.093
# Test accuracy: 0.649%
# Minibatch train loss at step 880 : 1.09656
# Minibatch train accuracy: 0.430%
# Test loss: 1.093
# Test accuracy: 0.651%
# Minibatch train loss at step 890 : 1.09091
# Minibatch train accuracy: 0.773%
# Test loss: 1.093
# Test accuracy: 0.653%
# Minibatch train loss at step 900 : 1.09254
# Minibatch train accuracy: 0.711%
# Test loss: 1.093
# Test accuracy: 0.656%
# Minibatch train loss at step 910 : 1.09216
# Minibatch train accuracy: 0.656%
# Test loss: 1.093
# Test accuracy: 0.658%
# Minibatch train loss at step 920 : 1.09138
# Minibatch train accuracy: 0.703%
# Test loss: 1.093
# Test accuracy: 0.660%
# Minibatch train loss at step 930 : 1.09249
# Minibatch train accuracy: 0.656%
# Test loss: 1.093
# Test accuracy: 0.664%
# Minibatch train loss at step 940 : 1.09723
# Minibatch train accuracy: 0.398%
# Test loss: 1.092
# Test accuracy: 0.668%
# Minibatch train loss at step 950 : 1.09697
# Minibatch train accuracy: 0.422%
# Test loss: 1.092
# Test accuracy: 0.668%
# Minibatch train loss at step 960 : 1.09866
# Minibatch train accuracy: 0.273%
# Test loss: 1.092
# Test accuracy: 0.669%
# Minibatch train loss at step 970 : 1.09505
# Minibatch train accuracy: 0.539%
# Test loss: 1.092
# Test accuracy: 0.670%
# Minibatch train loss at step 980 : 1.08879
# Minibatch train accuracy: 0.844%
# Test loss: 1.092
# Test accuracy: 0.671%
# Minibatch train loss at step 990 : 1.0903
# Minibatch train accuracy: 0.773%
# Test loss: 1.092
# Test accuracy: 0.677%
# Minibatch train loss at step 1000 : 1.0915
# Minibatch train accuracy: 0.688%
# Test loss: 1.092
# Test accuracy: 0.680%
# Minibatch train loss at step 1010 : 1.09106
# Minibatch train accuracy: 0.695%
# Test loss: 1.092
# Test accuracy: 0.681%
# Minibatch train loss at step 1020 : 1.09095
# Minibatch train accuracy: 0.688%
# Test loss: 1.092
# Test accuracy: 0.685%
# Minibatch train loss at step 1030 : 1.09477
# Minibatch train accuracy: 0.508%
# Test loss: 1.092
# Test accuracy: 0.688%
# Minibatch train loss at step 1040 : 1.09575
# Minibatch train accuracy: 0.508%
# Test loss: 1.092
# Test accuracy: 0.689%
# Minibatch train loss at step 1050 : 1.09977
# Minibatch train accuracy: 0.211%
# Test loss: 1.092
# Test accuracy: 0.689%
# Minibatch train loss at step 1060 : 1.09516
# Minibatch train accuracy: 0.492%
# Test loss: 1.091
# Test accuracy: 0.689%
# Minibatch train loss at step 1070 : 1.089
# Minibatch train accuracy: 0.766%
# Test loss: 1.091
# Test accuracy: 0.692%
# Minibatch train loss at step 1080 : 1.09099
# Minibatch train accuracy: 0.688%
# Test loss: 1.091
# Test accuracy: 0.694%
# Minibatch train loss at step 1090 : 1.09162
# Minibatch train accuracy: 0.641%
# Test loss: 1.091
# Test accuracy: 0.697%
# Minibatch train loss at step 1100 : 1.0904
# Minibatch train accuracy: 0.695%
# Test loss: 1.091
# Test accuracy: 0.697%
# Minibatch train loss at step 1110 : 1.09166
# Minibatch train accuracy: 0.648%
# Test loss: 1.091
# Test accuracy: 0.698%
# Minibatch train loss at step 1120 : 1.09274
# Minibatch train accuracy: 0.570%
# Test loss: 1.091
# Test accuracy: 0.699%
# Minibatch train loss at step 1130 : 1.09575
# Minibatch train accuracy: 0.453%
# Test loss: 1.091
# Test accuracy: 0.701%
# Minibatch train loss at step 1140 : 1.10013
# Minibatch train accuracy: 0.219%
# Test loss: 1.091
# Test accuracy: 0.701%
# Minibatch train loss at step 1150 : 1.09794
# Minibatch train accuracy: 0.383%
# Test loss: 1.091
# Test accuracy: 0.702%
# Minibatch train loss at step 1160 : 1.08897
# Minibatch train accuracy: 0.727%
# Test loss: 1.091
# Test accuracy: 0.702%
# Minibatch train loss at step 1170 : 1.09168
# Minibatch train accuracy: 0.641%
# Test loss: 1.090
# Test accuracy: 0.703%
# Minibatch train loss at step 1180 : 1.09552
# Minibatch train accuracy: 0.445%
# Test loss: 1.090
# Test accuracy: 0.704%
# Minibatch train loss at step 1190 : 1.08733
# Minibatch train accuracy: 0.789%
# Test loss: 1.090
# Test accuracy: 0.705%
# Minibatch train loss at step 1200 : 1.09072
# Minibatch train accuracy: 0.648%
# Test loss: 1.090
# Test accuracy: 0.706%
# Minibatch train loss at step 1210 : 1.09036
# Minibatch train accuracy: 0.633%
# Test loss: 1.090
# Test accuracy: 0.707%
# Minibatch train loss at step 1220 : 1.09618
# Minibatch train accuracy: 0.398%
# Test loss: 1.090
# Test accuracy: 0.706%
# Minibatch train loss at step 1230 : 1.09724
# Minibatch train accuracy: 0.352%
# Test loss: 1.090
# Test accuracy: 0.706%
# Minibatch train loss at step 1240 : 1.09696
# Minibatch train accuracy: 0.414%
# Test loss: 1.090
# Test accuracy: 0.706%
# Minibatch train loss at step 1250 : 1.08656
# Minibatch train accuracy: 0.812%
# Test loss: 1.090
# Test accuracy: 0.705%
# Minibatch train loss at step 1260 : 1.08854
# Minibatch train accuracy: 0.742%
# Test loss: 1.090
# Test accuracy: 0.706%
# Minibatch train loss at step 1270 : 1.09929
# Minibatch train accuracy: 0.281%
# Test loss: 1.089
# Test accuracy: 0.707%
# Minibatch train loss at step 1280 : 1.08706
# Minibatch train accuracy: 0.773%
# Test loss: 1.089
# Test accuracy: 0.707%
# Minibatch train loss at step 1290 : 1.09008
# Minibatch train accuracy: 0.641%
# Test loss: 1.089
# Test accuracy: 0.708%
# Minibatch train loss at step 1300 : 1.09002
# Minibatch train accuracy: 0.633%
# Test loss: 1.089
# Test accuracy: 0.708%
# Minibatch train loss at step 1310 : 1.09695
# Minibatch train accuracy: 0.367%
# Test loss: 1.089
# Test accuracy: 0.708%
# Minibatch train loss at step 1320 : 1.09653
# Minibatch train accuracy: 0.383%
# Test loss: 1.089
# Test accuracy: 0.708%
# Minibatch train loss at step 1330 : 1.09646
# Minibatch train accuracy: 0.422%
# Test loss: 1.089
# Test accuracy: 0.708%
# Minibatch train loss at step 1340 : 1.08685
# Minibatch train accuracy: 0.773%
# Test loss: 1.089
# Test accuracy: 0.708%
# Minibatch train loss at step 1350 : 1.08539
# Minibatch train accuracy: 0.828%
# Test loss: 1.089
# Test accuracy: 0.708%
# Minibatch train loss at step 1360 : 1.09835
# Minibatch train accuracy: 0.328%
# Test loss: 1.089
# Test accuracy: 0.708%
# Minibatch train loss at step 1370 : 1.08825
# Minibatch train accuracy: 0.711%
# Test loss: 1.088
# Test accuracy: 0.709%
# Minibatch train loss at step 1380 : 1.09034
# Minibatch train accuracy: 0.617%
# Test loss: 1.088
# Test accuracy: 0.709%
# Minibatch train loss at step 1390 : 1.08869
# Minibatch train accuracy: 0.656%
# Test loss: 1.088
# Test accuracy: 0.709%
# Minibatch train loss at step 1400 : 1.09602
# Minibatch train accuracy: 0.406%
# Test loss: 1.088
# Test accuracy: 0.709%
# Minibatch train loss at step 1410 : 1.0959
# Minibatch train accuracy: 0.398%
# Test loss: 1.088
# Test accuracy: 0.709%
# Minibatch train loss at step 1420 : 1.09921
# Minibatch train accuracy: 0.305%
# Test loss: 1.088
# Test accuracy: 0.709%
# Minibatch train loss at step 1430 : 1.08876
# Minibatch train accuracy: 0.672%
# Test loss: 1.088
# Test accuracy: 0.710%
# Minibatch train loss at step 1440 : 1.08379
# Minibatch train accuracy: 0.836%
# Test loss: 1.088
# Test accuracy: 0.710%
# Minibatch train loss at step 1450 : 1.09815
# Minibatch train accuracy: 0.336%
# Test loss: 1.088
# Test accuracy: 0.710%
# Minibatch train loss at step 1460 : 1.08734
# Minibatch train accuracy: 0.711%
# Test loss: 1.088
# Test accuracy: 0.711%
# Minibatch train loss at step 1470 : 1.08975
# Minibatch train accuracy: 0.617%
# Test loss: 1.088
# Test accuracy: 0.711%
# Minibatch train loss at step 1480 : 1.08724
# Minibatch train accuracy: 0.664%
# Test loss: 1.087
# Test accuracy: 0.712%
# Minibatch train loss at step 1490 : 1.09116
# Minibatch train accuracy: 0.570%
# Test loss: 1.087
# Test accuracy: 0.712%
# Minibatch train loss at step 1500 : 1.09244
# Minibatch train accuracy: 0.523%
# Test loss: 1.087
# Test accuracy: 0.712%
# Minibatch train loss at step 1510 : 1.09731
# Minibatch train accuracy: 0.359%
# Test loss: 1.087
# Test accuracy: 0.712%
# Minibatch train loss at step 1520 : 1.08624
# Minibatch train accuracy: 0.711%
# Test loss: 1.087
# Test accuracy: 0.712%
# Minibatch train loss at step 1530 : 1.08249
# Minibatch train accuracy: 0.852%
# Test loss: 1.087
# Test accuracy: 0.712%
# Minibatch train loss at step 1540 : 1.09712
# Minibatch train accuracy: 0.383%
# Test loss: 1.087
# Test accuracy: 0.712%
# Minibatch train loss at step 1550 : 1.08402
# Minibatch train accuracy: 0.766%
# Test loss: 1.087
# Test accuracy: 0.712%
# Minibatch train loss at step 1560 : 1.08832
# Minibatch train accuracy: 0.633%
# Test loss: 1.087
# Test accuracy: 0.713%
# Minibatch train loss at step 1570 : 1.08704
# Minibatch train accuracy: 0.664%
# Test loss: 1.087
# Test accuracy: 0.713%
# Minibatch train loss at step 1580 : 1.0881
# Minibatch train accuracy: 0.664%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1590 : 1.09022
# Minibatch train accuracy: 0.586%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1600 : 1.09654
# Minibatch train accuracy: 0.406%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1610 : 1.08197
# Minibatch train accuracy: 0.828%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1620 : 1.08614
# Minibatch train accuracy: 0.719%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1630 : 1.09351
# Minibatch train accuracy: 0.484%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1640 : 1.08212
# Minibatch train accuracy: 0.805%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1650 : 1.08584
# Minibatch train accuracy: 0.688%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1660 : 1.08575
# Minibatch train accuracy: 0.688%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1670 : 1.08854
# Minibatch train accuracy: 0.617%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1680 : 1.08983
# Minibatch train accuracy: 0.555%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1690 : 1.09768
# Minibatch train accuracy: 0.352%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1700 : 1.08047
# Minibatch train accuracy: 0.852%
# Test loss: 1.086
# Test accuracy: 0.713%
# Minibatch train loss at step 1710 : 1.08674
# Minibatch train accuracy: 0.695%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1720 : 1.09339
# Minibatch train accuracy: 0.469%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1730 : 1.08131
# Minibatch train accuracy: 0.805%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1740 : 1.08459
# Minibatch train accuracy: 0.703%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1750 : 1.08473
# Minibatch train accuracy: 0.695%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1760 : 1.08482
# Minibatch train accuracy: 0.688%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1770 : 1.09051
# Minibatch train accuracy: 0.523%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1780 : 1.09379
# Minibatch train accuracy: 0.445%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1790 : 1.08415
# Minibatch train accuracy: 0.719%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1800 : 1.0794
# Minibatch train accuracy: 0.859%
# Test loss: 1.085
# Test accuracy: 0.713%
# Minibatch train loss at step 1810 : 1.09777
# Minibatch train accuracy: 0.352%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1820 : 1.08171
# Minibatch train accuracy: 0.758%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1830 : 1.08595
# Minibatch train accuracy: 0.656%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1840 : 1.08383
# Minibatch train accuracy: 0.695%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1850 : 1.08261
# Minibatch train accuracy: 0.734%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1860 : 1.08996
# Minibatch train accuracy: 0.555%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1870 : 1.09458
# Minibatch train accuracy: 0.438%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1880 : 1.08791
# Minibatch train accuracy: 0.602%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1890 : 1.07566
# Minibatch train accuracy: 0.914%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1900 : 1.08247
# Minibatch train accuracy: 0.742%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1910 : 1.08412
# Minibatch train accuracy: 0.672%
# Test loss: 1.084
# Test accuracy: 0.713%
# Minibatch train loss at step 1920 : 1.08391
# Minibatch train accuracy: 0.688%
# Test loss: 1.083
# Test accuracy: 0.713%
# Minibatch train loss at step 1930 : 1.08327
# Minibatch train accuracy: 0.695%
# Test loss: 1.083
# Test accuracy: 0.713%
# Minibatch train loss at step 1940 : 1.08381
# Minibatch train accuracy: 0.703%
# Test loss: 1.083
# Test accuracy: 0.713%
# Minibatch train loss at step 1950 : 1.09374
# Minibatch train accuracy: 0.461%
# Test loss: 1.083
# Test accuracy: 0.713%
# Minibatch train loss at step 1960 : 1.09392
# Minibatch train accuracy: 0.461%
# Test loss: 1.083
# Test accuracy: 0.713%
# Minibatch train loss at step 1970 : 1.09288
# Minibatch train accuracy: 0.469%
# Test loss: 1.083
# Test accuracy: 0.713%
# Minibatch train loss at step 1980 : 1.07518
# Minibatch train accuracy: 0.906%
# Test loss: 1.083
# Test accuracy: 0.713%
# Minibatch train loss at step 1990 : 1.08149
# Minibatch train accuracy: 0.742%
# Test loss: 1.083
# Test accuracy: 0.713%
