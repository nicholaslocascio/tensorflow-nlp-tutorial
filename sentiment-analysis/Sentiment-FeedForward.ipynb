# %% [markdown]
# # TensorFlow FeedForward Sentiment Analysis

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
# tf.reset_default_graph()
session = tf.InteractiveSession()
import utils
import numpy as np

# %% [markdown]
# ### Data Preprocessing

# %%
X, y, index_to_word, sentences = utils.load_sentiment_data_bow()
X_train, y_train, X_test, y_test = utils.split_data(X, y)
vocab_size = X.shape[1]
n_classes = y.shape[1]

s_i = 50
print("Sentence: {}".format(sentences[s_i]))
print("BOW: {}".format(utils.bow_to_dict(X[s_i,:], index_to_word)))
print("Label: {}".format(utils.label_to_desc(y[s_i])))
# Out:
# Sentence: @VirginAmerica Is flight 769 on it's way? Was supposed to take off 30 minutes ago. Website still shows "On Time" not "In Flight". Thanks.
# BOW: {'is': 1.0, 'it': 1.0, 'thanks': 1.0, 'in': 1.0, 'still': 1.0, u'<UNK>': 1.0, '"': 4.0, "'": 1.0, '.': 3.0, 'to': 1.0, 'take': 1.0, 'way': 1.0, 'was': 1.0, '?': 1.0, 'shows': 1.0, 'website': 1.0, 'flight': 2.0, '@virginamerica': 1.0, 'not': 1.0, 'ago': 1.0, 'on': 2.0, 'off': 1.0, '30': 1.0, 's': 1.0, 'supposed': 1.0, 'time': 1.0, 'minutes': 1.0}
# Label: negative

# %% [markdown]
# ### Define TensorFlow Computation Graph

# %%
data_placeholder = tf.placeholder(tf.float32, shape=(None, vocab_size), name='data_placeholder')
labels_placeholder = tf.placeholder(tf.float32, shape=(None, n_classes), name='labels_placeholder')

# %%
# Define Weights
n_hidden_units_h0 = 512
n_hidden_units_h1 = 256

h0_weights = tf.Variable(
    tf.truncated_normal([vocab_size, n_hidden_units_h0]),
    name='h0_weights')
h0_biases = tf.Variable(tf.zeros([n_hidden_units_h0]),
                     name='h0_biases')


h1_weights = tf.Variable(
    tf.truncated_normal([n_hidden_units_h0, n_hidden_units_h1]),
    name='h1_weights')
h1_biases = tf.Variable(tf.zeros([n_hidden_units_h1]),
                     name='h1_biases')

h2_weights = tf.Variable(
    tf.truncated_normal([n_hidden_units_h1, n_classes]),
    name='h2_weights')
h2_biases = tf.Variable(tf.zeros([n_classes]),
                     name='h2_biases')

# %%
# Define Computation Graphs
hidden0 = tf.nn.relu(tf.matmul(data_placeholder, h0_weights) + h0_biases)
hidden1 = tf.nn.relu(tf.matmul(hidden0, h1_weights) + h1_biases)
logits = tf.matmul(hidden1, h2_weights) + h2_biases

# %%
# Define Loss Function + Optimizer
loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, labels_placeholder))

optimizer = tf.train.GradientDescentOptimizer(0.0002).minimize(loss)
prediction = tf.nn.softmax(logits)
prediction_is_correct = tf.equal(
    tf.argmax(logits, 1), tf.argmax(labels_placeholder, 1))
accuracy = tf.reduce_mean(tf.cast(prediction_is_correct, tf.float32))

# %%
# Train loop

num_steps = 1000
batch_size = 128

tf.initialize_all_variables().run()

for step in xrange(num_steps):
    offset = (step * batch_size) % (X_train.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = X_train[offset:(offset + batch_size), :]
    batch_labels = y_train[offset:(offset + batch_size), :]
    # We built our networking using placeholders. It's like we've made reservations for a party of 6.
    # So use feed_dict to fill what we reserved. And we can't show up with 9 people. 
    feed_dict_train = {data_placeholder: batch_data, labels_placeholder : batch_labels}
    # Run the optimizer, get the loss, get the predictions.
    # We can run multiple things at once and get their outputs
    _, loss_value_train, predictions_value_train, accuracy_value_train = session.run(
      [optimizer, loss, prediction, accuracy], feed_dict=feed_dict_train)
    if (step % 10 == 0):
        print "Minibatch train loss at step", step, ":", loss_value_train
        print "Minibatch train accuracy: %.3f%%" % accuracy_value_train
        feed_dict_test = {data_placeholder: X_test, labels_placeholder: y_test}
        loss_value_test, predictions_value_test, accuracy_value_test = session.run(
            [loss, prediction, accuracy], feed_dict=feed_dict_test)
        print "Test loss: %.3f" % loss_value_test
        print "Test accuracy: %.3f%%" % accuracy_value_test
# Out:
# Minibatch train loss at step 0 : 527.443
# Minibatch train accuracy: 0.352%
# Test loss: 471.953
# Test accuracy: 0.493%
# Minibatch train loss at step 5 : 657.233
# Minibatch train accuracy: 0.688%
# Test loss: 337.715
# Test accuracy: 0.644%
# Minibatch train loss at step 10 : 110.708
# Minibatch train accuracy: 0.570%
# Test loss: 138.643
# Test accuracy: 0.698%
# Minibatch train loss at step 15 : 95.7145
# Minibatch train accuracy: 0.586%
# Test loss: 150.376
# Test accuracy: 0.707%
# Minibatch train loss at step 20 : 138.203
# Minibatch train accuracy: 0.656%
# Test loss: 159.660
# Test accuracy: 0.397%
# Minibatch train loss at step 25 : 79.6419
# Minibatch train accuracy: 0.609%
# Test loss: 112.690
# Test accuracy: 0.699%
# Minibatch train loss at step 30 : 163.466
# Minibatch train accuracy: 0.695%
# Test loss: 82.916
# Test accuracy: 0.652%
# Minibatch train loss at step 35 : 109.506
# Minibatch train accuracy: 0.477%
# Test loss: 78.768
# Test accuracy: 0.625%
# Minibatch train loss at step 40 : 68.7234
# Minibatch train accuracy: 0.656%
# Test loss: 80.239
# Test accuracy: 0.685%
# Minibatch train loss at step 45 : 178.43
# Minibatch train accuracy: 0.469%
# Test loss: 170.730
# Test accuracy: 0.334%
# Minibatch train loss at step 50 : 124.661
# Minibatch train accuracy: 0.469%
# Test loss: 96.697
# Test accuracy: 0.719%
# Minibatch train loss at step 55 : 76.8337
# Minibatch train accuracy: 0.562%
# Test loss: 64.677
# Test accuracy: 0.595%
# Minibatch train loss at step 60 : 64.9993
# Minibatch train accuracy: 0.523%
# Test loss: 58.238
# Test accuracy: 0.655%
# Minibatch train loss at step 65 : 72.6249
# Minibatch train accuracy: 0.555%
# Test loss: 59.104
# Test accuracy: 0.686%
# Minibatch train loss at step 70 : 72.1953
# Minibatch train accuracy: 0.562%
# Test loss: 61.622
# Test accuracy: 0.625%
# Minibatch train loss at step 75 : 41.2123
# Minibatch train accuracy: 0.711%
# Test loss: 63.452
# Test accuracy: 0.706%
# Minibatch train loss at step 80 : 16.2522
# Minibatch train accuracy: 0.828%
# Test loss: 58.659
# Test accuracy: 0.704%
# Minibatch train loss at step 85 : 41.4147
# Minibatch train accuracy: 0.648%
# Test loss: 58.868
# Test accuracy: 0.705%
# Minibatch train loss at step 90 : 62.327
# Minibatch train accuracy: 0.719%
# Test loss: 46.495
# Test accuracy: 0.648%
# Minibatch train loss at step 95 : 50.9018
# Minibatch train accuracy: 0.641%
# Test loss: 43.550
# Test accuracy: 0.639%
# Minibatch train loss at step 100 : 39.7635
# Minibatch train accuracy: 0.695%
# Test loss: 41.349
# Test accuracy: 0.666%
# Minibatch train loss at step 105 : 35.7329
# Minibatch train accuracy: 0.688%
# Test loss: 43.047
# Test accuracy: 0.683%
# Minibatch train loss at step 110 : 31.8179
# Minibatch train accuracy: 0.711%
# Test loss: 40.055
# Test accuracy: 0.648%
# Minibatch train loss at step 115 : 29.7903
# Minibatch train accuracy: 0.633%
# Test loss: 41.231
# Test accuracy: 0.695%
# Minibatch train loss at step 120 : 28.0256
# Minibatch train accuracy: 0.703%
# Test loss: 38.675
# Test accuracy: 0.621%
# Minibatch train loss at step 125 : 43.2118
# Minibatch train accuracy: 0.594%
# Test loss: 48.072
# Test accuracy: 0.520%
# Minibatch train loss at step 130 : 44.5132
# Minibatch train accuracy: 0.703%
# Test loss: 36.613
# Test accuracy: 0.692%
# Minibatch train loss at step 135 : 46.0441
# Minibatch train accuracy: 0.500%
# Test loss: 38.186
# Test accuracy: 0.707%
# Minibatch train loss at step 140 : 67.6788
# Minibatch train accuracy: 0.562%
# Test loss: 50.480
# Test accuracy: 0.500%
# Minibatch train loss at step 145 : 35.8847
# Minibatch train accuracy: 0.602%
# Test loss: 35.072
# Test accuracy: 0.614%
# Minibatch train loss at step 150 : 49.6357
# Minibatch train accuracy: 0.594%
# Test loss: 55.410
# Test accuracy: 0.459%
# Minibatch train loss at step 155 : 40.9194
# Minibatch train accuracy: 0.555%
# Test loss: 32.841
# Test accuracy: 0.694%
# Minibatch train loss at step 160 : 42.1356
# Minibatch train accuracy: 0.562%
# Test loss: 35.938
# Test accuracy: 0.719%
# Minibatch train loss at step 165 : 34.9705
# Minibatch train accuracy: 0.797%
# Test loss: 31.435
# Test accuracy: 0.698%
# Minibatch train loss at step 170 : 8.50222
# Minibatch train accuracy: 0.875%
# Test loss: 35.210
# Test accuracy: 0.706%
# Minibatch train loss at step 175 : 19.8953
# Minibatch train accuracy: 0.766%
# Test loss: 28.959
# Test accuracy: 0.675%
# Minibatch train loss at step 180 : 29.192
# Minibatch train accuracy: 0.727%
# Test loss: 29.034
# Test accuracy: 0.654%
# Minibatch train loss at step 185 : 37.9069
# Minibatch train accuracy: 0.578%
# Test loss: 28.737
# Test accuracy: 0.692%
# Minibatch train loss at step 190 : 27.4887
# Minibatch train accuracy: 0.594%
# Test loss: 40.784
# Test accuracy: 0.726%
# Minibatch train loss at step 195 : 27.6528
# Minibatch train accuracy: 0.672%
# Test loss: 25.874
# Test accuracy: 0.681%
# Minibatch train loss at step 200 : 21.3863
# Minibatch train accuracy: 0.758%
# Test loss: 25.762
# Test accuracy: 0.667%
# Minibatch train loss at step 205 : 21.0917
# Minibatch train accuracy: 0.625%
# Test loss: 29.260
# Test accuracy: 0.711%
# Minibatch train loss at step 210 : 20.3396
# Minibatch train accuracy: 0.695%
# Test loss: 26.960
# Test accuracy: 0.707%
# Minibatch train loss at step 215 : 14.9393
# Minibatch train accuracy: 0.664%
# Test loss: 24.485
# Test accuracy: 0.657%
# Minibatch train loss at step 220 : 22.7982
# Minibatch train accuracy: 0.688%
# Test loss: 25.210
# Test accuracy: 0.640%
# Minibatch train loss at step 225 : 48.8897
# Minibatch train accuracy: 0.484%
# Test loss: 38.953
# Test accuracy: 0.724%
# Minibatch train loss at step 230 : 35.7872
# Minibatch train accuracy: 0.547%
# Test loss: 25.021
# Test accuracy: 0.625%
# Minibatch train loss at step 235 : 16.7394
# Minibatch train accuracy: 0.648%
# Test loss: 26.579
# Test accuracy: 0.570%
# Minibatch train loss at step 240 : 16.4551
# Minibatch train accuracy: 0.727%
# Test loss: 22.608
# Test accuracy: 0.662%
# Minibatch train loss at step 245 : 35.8733
# Minibatch train accuracy: 0.492%
# Test loss: 45.267
# Test accuracy: 0.393%
# Minibatch train loss at step 250 : 23.6329
# Minibatch train accuracy: 0.562%
# Test loss: 22.220
# Test accuracy: 0.648%
# Minibatch train loss at step 255 : 17.8816
# Minibatch train accuracy: 0.703%
# Test loss: 21.589
# Test accuracy: 0.688%
# Minibatch train loss at step 260 : 10.9364
# Minibatch train accuracy: 0.836%
# Test loss: 22.925
# Test accuracy: 0.689%
# Minibatch train loss at step 265 : 18.2232
# Minibatch train accuracy: 0.680%
# Test loss: 20.997
# Test accuracy: 0.655%
# Minibatch train loss at step 270 : 9.59993
# Minibatch train accuracy: 0.844%
# Test loss: 21.593
# Test accuracy: 0.703%
# Minibatch train loss at step 275 : 21.9311
# Minibatch train accuracy: 0.492%
# Test loss: 21.254
# Test accuracy: 0.702%
# Minibatch train loss at step 280 : 9.93415
# Minibatch train accuracy: 0.695%
# Test loss: 25.427
# Test accuracy: 0.724%
# Minibatch train loss at step 285 : 15.412
# Minibatch train accuracy: 0.727%
# Test loss: 19.804
# Test accuracy: 0.700%
# Minibatch train loss at step 290 : 15.0318
# Minibatch train accuracy: 0.695%
# Test loss: 18.907
# Test accuracy: 0.690%
# Minibatch train loss at step 295 : 9.9314
# Minibatch train accuracy: 0.680%
# Test loss: 18.459
# Test accuracy: 0.664%
# Minibatch train loss at step 300 : 23.6361
# Minibatch train accuracy: 0.695%
# Test loss: 17.881
# Test accuracy: 0.656%
# Minibatch train loss at step 305 : 11.7405
# Minibatch train accuracy: 0.602%
# Test loss: 23.055
# Test accuracy: 0.716%
# Minibatch train loss at step 310 : 16.1328
# Minibatch train accuracy: 0.617%
# Test loss: 19.317
# Test accuracy: 0.701%
# Minibatch train loss at step 315 : 28.9727
# Minibatch train accuracy: 0.516%
# Test loss: 22.299
# Test accuracy: 0.722%
# Minibatch train loss at step 320 : 15.4653
# Minibatch train accuracy: 0.648%
# Test loss: 16.770
# Test accuracy: 0.669%
# Minibatch train loss at step 325 : 19.2965
# Minibatch train accuracy: 0.609%
# Test loss: 19.107
# Test accuracy: 0.714%
# Minibatch train loss at step 330 : 14.7118
# Minibatch train accuracy: 0.680%
# Test loss: 18.032
# Test accuracy: 0.683%
# Minibatch train loss at step 335 : 23.3346
# Minibatch train accuracy: 0.594%
# Test loss: 19.872
# Test accuracy: 0.585%
# Minibatch train loss at step 340 : 15.7778
# Minibatch train accuracy: 0.586%
# Test loss: 20.495
# Test accuracy: 0.538%
# Minibatch train loss at step 345 : 16.2787
# Minibatch train accuracy: 0.641%
# Test loss: 22.377
# Test accuracy: 0.731%
# Minibatch train loss at step 350 : 6.99919
# Minibatch train accuracy: 0.836%
# Test loss: 18.034
# Test accuracy: 0.697%
# Minibatch train loss at step 355 : 17.6514
# Minibatch train accuracy: 0.703%
# Test loss: 15.768
# Test accuracy: 0.687%
# Minibatch train loss at step 360 : 7.90983
# Minibatch train accuracy: 0.875%
# Test loss: 19.593
# Test accuracy: 0.721%
# Minibatch train loss at step 365 : 19.1415
# Minibatch train accuracy: 0.555%
# Test loss: 16.148
# Test accuracy: 0.658%
# Minibatch train loss at step 370 : 8.83477
# Minibatch train accuracy: 0.688%
# Test loss: 17.336
# Test accuracy: 0.723%
# Minibatch train loss at step 375 : 16.7376
# Minibatch train accuracy: 0.594%
# Test loss: 22.326
# Test accuracy: 0.732%
# Minibatch train loss at step 380 : 13.425
# Minibatch train accuracy: 0.617%
# Test loss: 16.405
# Test accuracy: 0.714%
# Minibatch train loss at step 385 : 10.8243
# Minibatch train accuracy: 0.648%
# Test loss: 15.456
# Test accuracy: 0.610%
# Minibatch train loss at step 390 : 12.5989
# Minibatch train accuracy: 0.594%
# Test loss: 14.609
# Test accuracy: 0.682%
# Minibatch train loss at step 395 : 14.8929
# Minibatch train accuracy: 0.516%
# Test loss: 16.064
# Test accuracy: 0.714%
# Minibatch train loss at step 400 : 15.1708
# Minibatch train accuracy: 0.539%
# Test loss: 15.909
# Test accuracy: 0.698%
# Minibatch train loss at step 405 : 13.7742
# Minibatch train accuracy: 0.562%
# Test loss: 22.249
# Test accuracy: 0.467%
# Minibatch train loss at step 410 : 18.7816
# Minibatch train accuracy: 0.531%
# Test loss: 14.950
# Test accuracy: 0.697%
# Minibatch train loss at step 415 : 12.0411
# Minibatch train accuracy: 0.547%
# Test loss: 19.764
# Test accuracy: 0.489%
# Minibatch train loss at step 420 : 12.9373
# Minibatch train accuracy: 0.602%
# Test loss: 16.122
# Test accuracy: 0.706%
# Minibatch train loss at step 425 : 14.9213
# Minibatch train accuracy: 0.508%
# Test loss: 14.478
# Test accuracy: 0.610%
# Minibatch train loss at step 430 : 11.9415
# Minibatch train accuracy: 0.656%
# Test loss: 13.473
# Test accuracy: 0.667%
# Minibatch train loss at step 435 : 8.46229
# Minibatch train accuracy: 0.766%
# Test loss: 13.515
# Test accuracy: 0.663%
# Minibatch train loss at step 440 : 4.63285
# Minibatch train accuracy: 0.898%
# Test loss: 15.118
# Test accuracy: 0.695%
# Minibatch train loss at step 445 : 9.01173
# Minibatch train accuracy: 0.797%
# Test loss: 13.341
# Test accuracy: 0.678%
# Minibatch train loss at step 450 : 6.03001
# Minibatch train accuracy: 0.812%
# Test loss: 12.853
# Test accuracy: 0.658%
# Minibatch train loss at step 455 : 13.4646
# Minibatch train accuracy: 0.578%
# Test loss: 17.670
# Test accuracy: 0.497%
# Minibatch train loss at step 460 : 8.55034
# Minibatch train accuracy: 0.648%
# Test loss: 14.006
# Test accuracy: 0.721%
# Minibatch train loss at step 465 : 7.76796
# Minibatch train accuracy: 0.703%
# Test loss: 11.929
# Test accuracy: 0.686%
# Minibatch train loss at step 470 : 8.04608
# Minibatch train accuracy: 0.688%
# Test loss: 11.827
# Test accuracy: 0.682%
# Minibatch train loss at step 475 : 8.93273
# Minibatch train accuracy: 0.617%
# Test loss: 14.442
# Test accuracy: 0.722%
# Minibatch train loss at step 480 : 8.14642
# Minibatch train accuracy: 0.617%
# Test loss: 12.623
# Test accuracy: 0.698%
# Minibatch train loss at step 485 : 13.9909
# Minibatch train accuracy: 0.547%
# Test loss: 11.435
# Test accuracy: 0.690%
# Minibatch train loss at step 490 : 15.1282
# Minibatch train accuracy: 0.555%
# Test loss: 13.846
# Test accuracy: 0.543%
# Minibatch train loss at step 495 : 8.32376
# Minibatch train accuracy: 0.570%
# Test loss: 12.510
# Test accuracy: 0.578%
# Minibatch train loss at step 500 : 10.4873
# Minibatch train accuracy: 0.555%
# Test loss: 12.010
# Test accuracy: 0.597%
# Minibatch train loss at step 505 : 9.11116
# Minibatch train accuracy: 0.586%
# Test loss: 14.056
# Test accuracy: 0.530%
# Minibatch train loss at step 510 : 11.7437
# Minibatch train accuracy: 0.625%
# Test loss: 11.509
# Test accuracy: 0.651%
# Minibatch train loss at step 515 : 12.1571
# Minibatch train accuracy: 0.516%
# Test loss: 12.003
# Test accuracy: 0.697%
# Minibatch train loss at step 520 : 6.19829
# Minibatch train accuracy: 0.648%
# Test loss: 11.047
# Test accuracy: 0.638%
# Minibatch train loss at step 525 : 6.22101
# Minibatch train accuracy: 0.820%
# Test loss: 11.622
# Test accuracy: 0.622%
# Minibatch train loss at step 530 : 5.1375
# Minibatch train accuracy: 0.766%
# Test loss: 12.039
# Test accuracy: 0.706%
# Minibatch train loss at step 535 : 7.9684
# Minibatch train accuracy: 0.578%
# Test loss: 17.299
# Test accuracy: 0.730%
# Minibatch train loss at step 540 : 10.0956
# Minibatch train accuracy: 0.578%
# Test loss: 18.027
# Test accuracy: 0.730%
# Minibatch train loss at step 545 : 16.6361
# Minibatch train accuracy: 0.523%
# Test loss: 15.643
# Test accuracy: 0.490%
# Minibatch train loss at step 550 : 6.64097
# Minibatch train accuracy: 0.680%
# Test loss: 9.953
# Test accuracy: 0.687%
# Minibatch train loss at step 555 : 8.03773
# Minibatch train accuracy: 0.703%
# Test loss: 10.579
# Test accuracy: 0.620%
# Minibatch train loss at step 560 : 7.4444
# Minibatch train accuracy: 0.648%
# Test loss: 10.051
# Test accuracy: 0.696%
# Minibatch train loss at step 565 : 9.50367
# Minibatch train accuracy: 0.719%
# Test loss: 9.807
# Test accuracy: 0.665%
# Minibatch train loss at step 570 : 6.30844
# Minibatch train accuracy: 0.648%
# Test loss: 10.392
# Test accuracy: 0.709%
# Minibatch train loss at step 575 : 8.96861
# Minibatch train accuracy: 0.719%
# Test loss: 10.441
# Test accuracy: 0.624%
# Minibatch train loss at step 580 : 6.53346
# Minibatch train accuracy: 0.617%
# Test loss: 10.234
# Test accuracy: 0.609%
# Minibatch train loss at step 585 : 6.58239
# Minibatch train accuracy: 0.625%
# Test loss: 10.759
# Test accuracy: 0.714%
# Minibatch train loss at step 590 : 8.96563
# Minibatch train accuracy: 0.570%
# Test loss: 17.628
# Test accuracy: 0.443%
# Minibatch train loss at step 595 : 7.75589
# Minibatch train accuracy: 0.656%
# Test loss: 9.494
# Test accuracy: 0.669%
# Minibatch train loss at step 600 : 8.3354
# Minibatch train accuracy: 0.680%
# Test loss: 9.802
# Test accuracy: 0.644%
# Minibatch train loss at step 605 : 8.52571
# Minibatch train accuracy: 0.547%
# Test loss: 9.698
# Test accuracy: 0.662%
# Minibatch train loss at step 610 : 12.8748
# Minibatch train accuracy: 0.516%
# Test loss: 11.146
# Test accuracy: 0.714%
# Minibatch train loss at step 615 : 5.27504
# Minibatch train accuracy: 0.781%
# Test loss: 9.608
# Test accuracy: 0.660%
# Minibatch train loss at step 620 : 5.28405
# Minibatch train accuracy: 0.727%
# Test loss: 10.689
# Test accuracy: 0.707%
# Minibatch train loss at step 625 : 4.70554
# Minibatch train accuracy: 0.664%
# Test loss: 11.179
# Test accuracy: 0.720%
# Minibatch train loss at step 630 : 4.98148
# Minibatch train accuracy: 0.719%
# Test loss: 10.279
# Test accuracy: 0.562%
# Minibatch train loss at step 635 : 8.96007
# Minibatch train accuracy: 0.555%
# Test loss: 8.921
# Test accuracy: 0.658%
# Minibatch train loss at step 640 : 9.14525
# Minibatch train accuracy: 0.531%
# Test loss: 10.794
# Test accuracy: 0.724%
# Minibatch train loss at step 645 : 6.43862
# Minibatch train accuracy: 0.766%
# Test loss: 8.492
# Test accuracy: 0.645%
# Minibatch train loss at step 650 : 4.05333
# Minibatch train accuracy: 0.773%
# Test loss: 8.472
# Test accuracy: 0.650%
# Minibatch train loss at step 655 : 4.28046
# Minibatch train accuracy: 0.734%
# Test loss: 9.084
# Test accuracy: 0.603%
# Minibatch train loss at step 660 : 7.0608
# Minibatch train accuracy: 0.664%
# Test loss: 11.028
# Test accuracy: 0.513%
# Minibatch train loss at step 665 : 6.15358
# Minibatch train accuracy: 0.664%
# Test loss: 8.487
# Test accuracy: 0.643%
# Minibatch train loss at step 670 : 7.56999
# Minibatch train accuracy: 0.555%
# Test loss: 10.195
# Test accuracy: 0.719%
# Minibatch train loss at step 675 : 4.00784
# Minibatch train accuracy: 0.711%
# Test loss: 8.010
# Test accuracy: 0.676%
# Minibatch train loss at step 680 : 6.12706
# Minibatch train accuracy: 0.586%
# Test loss: 10.044
# Test accuracy: 0.519%
# Minibatch train loss at step 685 : 4.94754
# Minibatch train accuracy: 0.664%
# Test loss: 11.278
# Test accuracy: 0.725%
# Minibatch train loss at step 690 : 7.65805
# Minibatch train accuracy: 0.648%
# Test loss: 8.445
# Test accuracy: 0.684%
# Minibatch train loss at step 695 : 5.2918
# Minibatch train accuracy: 0.617%
# Test loss: 10.676
# Test accuracy: 0.521%
# Minibatch train loss at step 700 : 9.11272
# Minibatch train accuracy: 0.547%
# Test loss: 7.860
# Test accuracy: 0.692%
# Minibatch train loss at step 705 : 3.12534
# Minibatch train accuracy: 0.828%
# Test loss: 8.038
# Test accuracy: 0.685%
# Minibatch train loss at step 710 : 6.3217
# Minibatch train accuracy: 0.844%
# Test loss: 8.011
# Test accuracy: 0.663%
# Minibatch train loss at step 715 : 5.22855
# Minibatch train accuracy: 0.773%
# Test loss: 9.276
# Test accuracy: 0.541%
# Minibatch train loss at step 720 : 6.82537
# Minibatch train accuracy: 0.648%
# Test loss: 11.630
# Test accuracy: 0.479%
# Minibatch train loss at step 725 : 12.4415
# Minibatch train accuracy: 0.484%
# Test loss: 9.645
# Test accuracy: 0.718%
# Minibatch train loss at step 730 : 6.99785
# Minibatch train accuracy: 0.711%
# Test loss: 7.359
# Test accuracy: 0.685%
# Minibatch train loss at step 735 : 2.78237
# Minibatch train accuracy: 0.820%
# Test loss: 7.324
# Test accuracy: 0.685%
# Minibatch train loss at step 740 : 2.92095
# Minibatch train accuracy: 0.773%
# Test loss: 7.406
# Test accuracy: 0.659%
# Minibatch train loss at step 745 : 4.32081
# Minibatch train accuracy: 0.633%
# Test loss: 9.279
# Test accuracy: 0.720%
# Minibatch train loss at step 750 : 7.21065
# Minibatch train accuracy: 0.633%
# Test loss: 8.530
# Test accuracy: 0.577%
# Minibatch train loss at step 755 : 5.87365
# Minibatch train accuracy: 0.664%
# Test loss: 7.120
# Test accuracy: 0.677%
# Minibatch train loss at step 760 : 6.16567
# Minibatch train accuracy: 0.570%
# Test loss: 7.443
# Test accuracy: 0.701%
# Minibatch train loss at step 765 : 7.74524
# Minibatch train accuracy: 0.680%
# Test loss: 7.891
# Test accuracy: 0.578%
# Minibatch train loss at step 770 : 5.17851
# Minibatch train accuracy: 0.656%
# Test loss: 7.118
# Test accuracy: 0.661%
# Minibatch train loss at step 775 : 7.804
# Minibatch train accuracy: 0.641%
# Test loss: 7.439
# Test accuracy: 0.622%
# Minibatch train loss at step 780 : 6.69215
# Minibatch train accuracy: 0.531%
# Test loss: 7.121
# Test accuracy: 0.637%
# Minibatch train loss at step 785 : 6.54164
# Minibatch train accuracy: 0.602%
# Test loss: 7.165
# Test accuracy: 0.689%
# Minibatch train loss at step 790 : 15.4505
# Minibatch train accuracy: 0.484%
# Test loss: 11.905
# Test accuracy: 0.452%
# Minibatch train loss at step 795 : 3.17825
# Minibatch train accuracy: 0.672%
# Test loss: 9.296
# Test accuracy: 0.730%
# Minibatch train loss at step 800 : 4.4818
# Minibatch train accuracy: 0.828%
# Test loss: 7.085
# Test accuracy: 0.670%
# Minibatch train loss at step 805 : 5.61119
# Minibatch train accuracy: 0.719%
# Test loss: 7.176
# Test accuracy: 0.615%
# Minibatch train loss at step 810 : 6.20123
# Minibatch train accuracy: 0.625%
# Test loss: 6.851
# Test accuracy: 0.690%
# Minibatch train loss at step 815 : 6.02653
# Minibatch train accuracy: 0.633%
# Test loss: 10.084
# Test accuracy: 0.473%
# Minibatch train loss at step 820 : 6.99722
# Minibatch train accuracy: 0.688%
# Test loss: 6.481
# Test accuracy: 0.637%
# Minibatch train loss at step 825 : 3.34527
# Minibatch train accuracy: 0.680%
# Test loss: 8.370
# Test accuracy: 0.732%
# Minibatch train loss at step 830 : 4.9856
# Minibatch train accuracy: 0.656%
# Test loss: 6.210
# Test accuracy: 0.662%
# Minibatch train loss at step 835 : 3.98361
# Minibatch train accuracy: 0.625%
# Test loss: 7.833
# Test accuracy: 0.711%
# Minibatch train loss at step 840 : 3.54969
# Minibatch train accuracy: 0.719%
# Test loss: 6.660
# Test accuracy: 0.706%
# Minibatch train loss at step 845 : 5.01502
# Minibatch train accuracy: 0.664%
# Test loss: 6.408
# Test accuracy: 0.707%
# Minibatch train loss at step 850 : 6.54056
# Minibatch train accuracy: 0.500%
# Test loss: 10.374
# Test accuracy: 0.435%
# Minibatch train loss at step 855 : 3.78
# Minibatch train accuracy: 0.758%
# Test loss: 6.185
# Test accuracy: 0.635%
# Minibatch train loss at step 860 : 3.71126
# Minibatch train accuracy: 0.648%
# Test loss: 6.199
# Test accuracy: 0.640%
# Minibatch train loss at step 865 : 8.20987
# Minibatch train accuracy: 0.539%
# Test loss: 7.630
# Test accuracy: 0.721%
# Minibatch train loss at step 870 : 6.74181
# Minibatch train accuracy: 0.492%
# Test loss: 8.309
# Test accuracy: 0.501%
# Minibatch train loss at step 875 : 8.4784
# Minibatch train accuracy: 0.539%
# Test loss: 7.761
# Test accuracy: 0.720%
# Minibatch train loss at step 880 : 4.83869
# Minibatch train accuracy: 0.609%
# Test loss: 8.181
# Test accuracy: 0.536%
# Minibatch train loss at step 885 : 3.52611
# Minibatch train accuracy: 0.750%
# Test loss: 7.253
# Test accuracy: 0.571%
# Minibatch train loss at step 890 : 4.04868
# Minibatch train accuracy: 0.703%
# Test loss: 7.857
# Test accuracy: 0.723%
# Minibatch train loss at step 895 : 1.89497
# Minibatch train accuracy: 0.859%
# Test loss: 6.268
# Test accuracy: 0.701%
# Minibatch train loss at step 900 : 3.48619
# Minibatch train accuracy: 0.750%
# Test loss: 6.053
# Test accuracy: 0.689%
# Minibatch train loss at step 905 : 6.0903
# Minibatch train accuracy: 0.539%
# Test loss: 12.726
# Test accuracy: 0.363%
# Minibatch train loss at step 910 : 3.69831
# Minibatch train accuracy: 0.703%
# Test loss: 5.746
# Test accuracy: 0.672%
# Minibatch train loss at step 915 : 3.83966
# Minibatch train accuracy: 0.727%
# Test loss: 5.627
# Test accuracy: 0.661%
# Minibatch train loss at step 920 : 4.50648
# Minibatch train accuracy: 0.602%
# Test loss: 5.834
# Test accuracy: 0.693%
# Minibatch train loss at step 925 : 3.46744
# Minibatch train accuracy: 0.688%
# Test loss: 5.639
# Test accuracy: 0.685%
# Minibatch train loss at step 930 : 2.42093
# Minibatch train accuracy: 0.758%
# Test loss: 5.627
# Test accuracy: 0.670%
# Minibatch train loss at step 935 : 3.32304
# Minibatch train accuracy: 0.648%
# Test loss: 5.554
# Test accuracy: 0.642%
# Minibatch train loss at step 940 : 3.45117
# Minibatch train accuracy: 0.617%
# Test loss: 6.648
# Test accuracy: 0.545%
# Minibatch train loss at step 945 : 5.15105
# Minibatch train accuracy: 0.578%
# Test loss: 8.893
# Test accuracy: 0.726%
# Minibatch train loss at step 950 : 8.12322
# Minibatch train accuracy: 0.570%
# Test loss: 7.968
# Test accuracy: 0.512%
# Minibatch train loss at step 955 : 5.84567
# Minibatch train accuracy: 0.516%
# Test loss: 7.536
# Test accuracy: 0.728%
# Minibatch train loss at step 960 : 5.12407
# Minibatch train accuracy: 0.492%
# Test loss: 7.688
# Test accuracy: 0.487%
# Minibatch train loss at step 965 : 4.00141
# Minibatch train accuracy: 0.594%
# Test loss: 5.659
# Test accuracy: 0.653%
# Minibatch train loss at step 970 : 7.86465
# Minibatch train accuracy: 0.398%
# Test loss: 8.599
# Test accuracy: 0.729%
# Minibatch train loss at step 975 : 3.77694
# Minibatch train accuracy: 0.711%
# Test loss: 5.776
# Test accuracy: 0.633%
# Minibatch train loss at step 980 : 3.07964
# Minibatch train accuracy: 0.680%
# Test loss: 8.008
# Test accuracy: 0.726%
# Minibatch train loss at step 985 : 1.33661
# Minibatch train accuracy: 0.883%
# Test loss: 6.370
# Test accuracy: 0.717%
# Minibatch train loss at step 990 : 3.195
# Minibatch train accuracy: 0.773%
# Test loss: 5.446
# Test accuracy: 0.657%
# Minibatch train loss at step 995 : 7.97609
# Minibatch train accuracy: 0.758%
# Test loss: 5.530
# Test accuracy: 0.690%
